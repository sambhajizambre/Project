# %% [markdown]
# <a href="https://colab.research.google.com/github/sambhajizambre/Project/blob/main/seed%20dataset%20decision%20tree%20classifier%20algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,roc_curve, classification_report

# %%
df=pd.read_excel('/content/drive/MyDrive/python/seeds_dataset.xlsx')
df.head(5)
# Out:
#     Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# 0                  2.221                    5.220             1
# 1                  1.018                    4.956             1
# 2                  2.699                    4.825             1
# 3                  2.259                    4.805             1
# 4                  1.355                    5.175             1

# %%
df.shape
# Out:
# (210, 8)

# %%
df.describe()
# Out:
#              Area   Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# count  210.000000  210.000000   210.000000        210.000000       210.000000
# mean    14.847524   14.559286     0.870999          5.628533         3.258605
# std      2.909699    1.305959     0.023629          0.443063         0.377714
# min     10.590000   12.410000     0.808100          4.899000         2.630000
# 25%     12.270000   13.450000     0.856900          5.262250         2.944000
# 50%     14.355000   14.320000     0.873450          5.523500         3.237000
# 75%     17.305000   15.715000     0.887775          5.979750         3.561750
# max     21.180000   17.250000     0.918300          6.675000         4.033000
#
#        Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# count             210.000000               210.000000    210.000000
# mean                3.700201                 5.408071      2.000000
# ...

# %%
df.isnull().sum()
# Out:
# Area                       0
# Perimeter                  0
# Compactness                0
# Length of Kernel           0
# Width of Kernel            0
# Asymmetry coefficient      0
# Length of kernel groove    0
# Class (1_2_3               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Area                     210 non-null    float64
#  1   Perimeter                210 non-null    float64
#  2   Compactness              210 non-null    float64
#  3   Length of Kernel         210 non-null    float64
#  4   Width of Kernel          210 non-null    float64
#  5   Asymmetry coefficient    210 non-null    float64
#  6   Length of kernel groove  210 non-null    float64
#  7   Class (1_2_3             210 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 13.2 KB

# %%
df=df.round(2)
df
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84         0.87              5.76             3.31
# 1    14.88      14.57         0.88              5.55             3.33
# 2    14.29      14.09         0.90              5.29             3.34
# 3    13.84      13.94         0.90              5.32             3.38
# 4    16.14      14.99         0.90              5.66             3.56
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20         0.88              5.14             2.98
# 206  11.23      12.88         0.85              5.14             2.80
# 207  13.20      13.66         0.89              5.24             3.23
# 208  11.84      13.21         0.85              5.18             2.84
# 209  12.30      13.34         0.87              5.24             2.97
#
#      Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# ...

# %% [markdown]
# # heatmap

# %%
plt.figure(figsize=(8,8))
cor=df.corr()
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.ylim(8,0)
# Out:
# (8.0, 0.0)

# %% [markdown]
# # Distribution Plot for one by one variable

# %%
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Area'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Perimeter'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Compactness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Length of Kernel'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Width of Kernel'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Asymmetry coefficient'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Length of kernel groove'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Class (1_2_3'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84         0.87              5.76             3.31
# 1    14.88      14.57         0.88              5.55             3.33
# 2    14.29      14.09         0.90              5.29             3.34
# 3    13.84      13.94         0.90              5.32             3.38
# 4    16.14      14.99         0.90              5.66             3.56
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20         0.88              5.14             2.98
# 206  11.23      12.88         0.85              5.14             2.80
# 207  13.20      13.66         0.89              5.24             3.23
# 208  11.84      13.21         0.85              5.18             2.84
# 209  12.30      13.34         0.87              5.24             2.97
#
#      Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# ...

# %%
df
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84         0.87              5.76             3.31
# 1    14.88      14.57         0.88              5.55             3.33
# 2    14.29      14.09         0.90              5.29             3.34
# 3    13.84      13.94         0.90              5.32             3.38
# 4    16.14      14.99         0.90              5.66             3.56
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20         0.88              5.14             2.98
# 206  11.23      12.88         0.85              5.14             2.80
# 207  13.20      13.66         0.89              5.24             3.23
# 208  11.84      13.21         0.85              5.18             2.84
# 209  12.30      13.34         0.87              5.24             2.97
#
#      Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# ...

# %% [markdown]
# # checking VIF value

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df[['Area', 'Perimeter','Compactness','Length of Kernel','Width of Kernel','Asymmetry coefficient','Length of kernel groove']]
#VIF dataframe
vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
# calculating VIF for each feature
vif_df["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df)
# Out:
#                    feature           VIF
# 0                     Area   4695.485975
# 1                Perimeter  19229.360535
# 2              Compactness   5198.083692
# 3         Length of Kernel   7988.548677
# 4          Width of Kernel   7295.162001
# 5    Asymmetry coefficient      9.417769
# 6  Length of kernel groove   1318.561552

# %%
df1 = df.drop('Length of Kernel', axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df1[['Area', 'Perimeter','Compactness','Width of Kernel','Asymmetry coefficient','Length of kernel groove']]
#VIF dataframe
vif_df1 = pd.DataFrame()
vif_df1["feature"] = X.columns
# calculating VIF for each feature
vif_df1["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df1)
# Out:
#                    feature          VIF
# 0                     Area  4583.769650
# 1                Perimeter  6993.870211
# 2              Compactness  5179.016781
# 3          Width of Kernel  6975.638868
# 4    Asymmetry coefficient     9.377111
# 5  Length of kernel groove  1182.589323

# %%
df2 = df1.drop('Width of Kernel', axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df2[['Area', 'Perimeter','Compactness','Asymmetry coefficient','Length of kernel groove']]
#VIF dataframe
vif_df2 = pd.DataFrame()
vif_df2["feature"] = X.columns
# calculating VIF for each feature
vif_df2["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df2)
# Out:
#                    feature          VIF
# 0                     Area   647.345453
# 1                Perimeter  6063.796882
# 2              Compactness  1056.171329
# 3    Asymmetry coefficient     8.915704
# 4  Length of kernel groove  1011.011410

# %%
df2
# Out:
#       Area  Perimeter  Compactness  Asymmetry coefficient  \
# 0    15.26      14.84         0.87                   2.22
# 1    14.88      14.57         0.88                   1.02
# 2    14.29      14.09         0.90                   2.70
# 3    13.84      13.94         0.90                   2.26
# 4    16.14      14.99         0.90                   1.36
# ..     ...        ...          ...                    ...
# 205  12.19      13.20         0.88                   3.63
# 206  11.23      12.88         0.85                   4.32
# 207  13.20      13.66         0.89                   8.32
# 208  11.84      13.21         0.85                   3.60
# 209  12.30      13.34         0.87                   5.64
#
#      Length of kernel groove  Class (1_2_3
# 0                       5.22             1
# 1                       4.96             1
# 2                       4.82             1
# 3                       4.80             1
# 4                       5.18             1
# ...

# %%
df3 = df2.drop('Length of kernel groove', axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df3[['Area', 'Perimeter','Compactness','Asymmetry coefficient']]
#VIF dataframe
vif_df3 = pd.DataFrame()
vif_df3["feature"] = X.columns
# calculating VIF for each feature
vif_df3["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df3)
# Out:
#                  feature          VIF
# 0                   Area   467.974278
# 1              Perimeter  2305.112009
# 2            Compactness   757.117209
# 3  Asymmetry coefficient     7.676497

# %%
plt.figure(figsize=(8,8))
cor=df3.corr()
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.ylim(8,0)
# Out:
# (8.0, 0.0)

# %%
df4 = df3.drop('Perimeter', axis=1)
df4
# Out:
#       Area  Compactness  Asymmetry coefficient  Class (1_2_3
# 0    15.26         0.87                   2.22             1
# 1    14.88         0.88                   1.02             1
# 2    14.29         0.90                   2.70             1
# 3    13.84         0.90                   2.26             1
# 4    16.14         0.90                   1.36             1
# ..     ...          ...                    ...           ...
# 205  12.19         0.88                   3.63             3
# 206  11.23         0.85                   4.32             3
# 207  13.20         0.89                   8.32             3
# 208  11.84         0.85                   3.60             3
# 209  12.30         0.87                   5.64             3
#
# [210 rows x 4 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df4[['Area','Compactness','Asymmetry coefficient']]
#VIF dataframe
vif_df4 = pd.DataFrame()
vif_df4["feature"] = X.columns
# calculating VIF for each feature
vif_df4["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df4)
# Out:
#                  feature        VIF
# 0                   Area  33.557007
# 1            Compactness  45.960602
# 2  Asymmetry coefficient   7.129399

# %%
plt.figure(figsize=(8,8))
cor=df4.corr()
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.ylim(8,0)
# Out:
# (8.0, 0.0)

# %%
#--Checking Outliers
plt.figure(figsize=(15,15))
pos = 1
for i in df.columns:
    plt.subplot(3, 4, pos)
    sns.boxplot(df[i])
    pos += 1
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# # Detecting the outliers using IQR and removing them.

# %%
col_names=['Area', 'Perimeter', 'Compactness', 'Length of Kernel',
       'Width of Kernel', 'Asymmetry coefficient', 'Length of kernel groove']
display(col_names)
for i in col_names:
    q1, q2, q3 = df[i].quantile([0.25,0.5,0.75])
    IQR = q3 - q1
    lower_cap=q1-1.5*IQR
    upper_cap=q3+1.5*IQR
    df[i]=df[i].apply(lambda x: upper_cap if x>(upper_cap) else (lower_cap if x<(lower_cap) else x))

    
print("Old Shape: ", df[i].shape)
print("New Shape: ", df[i].shape)
# Out:
# ['Area',
#  'Perimeter',
#  'Compactness',
#  'Length of Kernel',
#  'Width of Kernel',
#  'Asymmetry coefficient',
#  'Length of kernel groove']
# Old Shape:  (204,)
# New Shape:  (204,)

# %%
df.shape
# Out:
# (204, 8)

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['Length of kernel groove'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Length of kernel groove'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['Length of kernel groove'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['Length of kernel groove'] <= (Q1-1.5*IQR))
 
''' Removing the Outliers '''
df.drop(upper[0], inplace = True)
df.drop(lower[0], inplace = True)
 
print("New Shape: ", df.shape)
# Out:
# Old Shape:  (204, 8)
# New Shape:  (204, 8)

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['Asymmetry coefficient'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Asymmetry coefficient'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['Asymmetry coefficient'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['Asymmetry coefficient'] <= (Q1-1.5*IQR))
 
''' Removing the Outliers '''
df.drop(upper[0], inplace = True)
df.drop(lower[0], inplace = True)
 
print("New Shape: ", df.shape)
# Out:
# Old Shape:  (206, 8)
# New Shape:  (204, 8)

# %% [markdown]
# # Annova Test

# %%
def f_test_target(feature, df_arg):
    data_dict = {}
    target_class = ['class_1', 'class_2', 'class_3']
    for class_id in range(1, 4):
        data_dict[target_class[class_id - 1]] = list(df_arg.loc[df_arg['Class_(1, 2, 3)'] == class_id][feature])
    df_new = pd.DataFrame(data_dict)
    f_start, p_value = stats.f_oneway(df_new[target_class[0]], df_new[target_class[1]], df_new[target_class[2]])
    if p_value > 0.05:
        print(feature, 'One-way ANOVA, Mean across different class are same')
    else:
        print(feature, 'One-way ANOVA, Mean across different class are different')

# %%
for feature in df.drop('Class (1_2_3', axis = 1).columns:
    f_test_target(feature, df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class_(1, 2, 3)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Feature scaling

# %%
df_X = df.drop('Class (1_2_3', axis =1)
df_y = df['Class (1_2_3']
scaler = StandardScaler().fit(df_X)
df_X_scaled = pd.DataFrame(scaler.transform(df_X), columns = df_X.columns)
df_X_scaled.describe().T
# Out:
#                          count          mean      std       min       25%  \
# Area                     204.0  2.612289e-16  1.00246 -1.501524 -0.887458
# Perimeter                204.0  0.000000e+00  1.00246 -1.677086 -0.865662
# Compactness              204.0 -2.472967e-15  1.00246 -2.361513 -0.562265
# Length of Kernel         204.0  1.044916e-16  1.00246 -1.665862 -0.854044
# Width of Kernel          204.0 -5.572884e-16  1.00246 -1.721962 -0.835840
# Asymmetry coefficient    204.0  2.786442e-16  1.00246 -1.966887 -0.794336
# Length of kernel groove  204.0 -1.044916e-15  1.00246 -1.813765 -0.761686
#
#                               50%       75%       max
# Area                    -0.169753  0.853691  2.156962
# Perimeter               -0.153987  0.910647  2.036666
# Compactness             -0.112453  0.787171  2.136607
# Length of Kernel        -0.222631  0.820329  2.348125
# Width of Kernel         -0.030275  0.782004  2.037344
# ...

# %% [markdown]
# # Outliers handling

# %%
df_X_scaled = np.clip(df_X_scaled, -3, 3)
df_X_scaled.describe().T
# Out:
#                          count          mean      std       min       25%  \
# Area                     204.0  2.612289e-16  1.00246 -1.501524 -0.887458
# Perimeter                204.0  0.000000e+00  1.00246 -1.677086 -0.865662
# Compactness              204.0 -2.472967e-15  1.00246 -2.361513 -0.562265
# Length of Kernel         204.0  1.044916e-16  1.00246 -1.665862 -0.854044
# Width of Kernel          204.0 -5.572884e-16  1.00246 -1.721962 -0.835840
# Asymmetry coefficient    204.0  2.786442e-16  1.00246 -1.966887 -0.794336
# Length of kernel groove  204.0 -1.044916e-15  1.00246 -1.813765 -0.761686
#
#                               50%       75%       max
# Area                    -0.169753  0.853691  2.156962
# Perimeter               -0.153987  0.910647  2.036666
# Compactness             -0.112453  0.787171  2.136607
# Length of Kernel        -0.222631  0.820329  2.348125
# Width of Kernel         -0.030275  0.782004  2.037344
# ...

# %%
sns.pairplot(df);

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),
            annot=True,
            linewidths=.5,
            center=0,
            cbar=False,
            cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['Class (1_2_3']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Decision Tree classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
X=df4.drop('Class (1_2_3',axis=1)
y=df4['Class (1_2_3']

# %%
dt.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=3,test_size=0.30)

# %%
dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred=dt.predict(X_test)
y_test_prob=dt.predict_proba(X_test)

# %%
print ('Confusion Matrix -Test :','\n',confusion_matrix(y_test,y_test_pred))

print ('Overall accuracy -Test :',accuracy_score(y_test,y_test_pred))


print ('AUC -Test :', roc_auc_score(y_test,y_test_prob,multi_class='ovr'))
# Out:
# Confusion Matrix -Test :
#  [[21  1  0]
#  [ 3 20  0]
#  [ 2  0 16]]
# Overall accuracy -Test : 0.9047619047619048
# AUC -Test : 0.9276747235522421

# %%
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.81      0.95      0.88        22
#            2       0.95      0.87      0.91        23
#            3       1.00      0.89      0.94        18
#
#     accuracy                           0.90        63
#    macro avg       0.92      0.90      0.91        63
# weighted avg       0.92      0.90      0.91        63

# %% [markdown]
# # Acurracy testing using hyperparameter

# %%
# Function to split the dataset
def splitdataset(df):
# Separating the target variable
	X = df.drop(['Class (1_2_3'], axis=1)
	Y = df['Class (1_2_3']

	# Splitting the dataset into train and test
	X_train, X_test, y_train, y_test = train_test_split(
	X, Y, test_size = 0.3, random_state = 100)
	
	return X, Y, X_train, X_test, y_train, y_test
# Function to perform training with giniIndex.
def train_using_gini(X_train, X_test, y_train):

	# Creating the classifier object
	clf_gini = DecisionTreeClassifier(criterion = "gini",
			random_state = 100,max_depth=3, min_samples_leaf=5)

	# Performing training
	clf_gini.fit(X_train, y_train)
	return clf_gini
	
# Function to perform training with entropy.
def tarin_using_entropy(X_train, X_test, y_train):

	# Decision tree with entropy
	clf_entropy = DecisionTreeClassifier(
			criterion = "entropy", random_state = 100,
			max_depth = 3, min_samples_leaf = 5)

	# Performing training
	clf_entropy.fit(X_train, y_train)
	return clf_entropy


# Function to make predictions
def prediction(X_test, clf_object):

	# Predicton on test with giniIndex
	y_pred = clf_object.predict(X_test)
	print("Predicted values:")
	print(y_pred)
	return y_pred
	
# Function to calculate accuracy
def cal_accuracy(y_test, y_pred):
	
	print("Confusion Matrix: ",
		confusion_matrix(y_test, y_pred))
	
	print ("Accuracy : ",
	accuracy_score(y_test,y_pred)*100)
	
	print("Report : ",
	classification_report(y_test, y_pred))

# Driver code
def main():
	
	# Building Phase
	data = df
	X, Y, X_train, X_test, y_train, y_test = splitdataset(data)
	clf_gini = train_using_gini(X_train, X_test, y_train)
	clf_entropy = tarin_using_entropy(X_train, X_test, y_train)
	
	# Operational Phase
	print("Results Using Gini Index:")
	
	# Prediction using gini
	y_pred_gini = prediction(X_test, clf_gini)
	cal_accuracy(y_test, y_pred_gini)
	
	print("Results Using Entropy:")
	# Prediction using entropy
	y_pred_entropy = prediction(X_test, clf_entropy)
	cal_accuracy(y_test, y_pred_entropy)
	
	
# Calling main function
if __name__=="__main__":
	main()
# Out:
# Results Using Gini Index:
# Predicted values:
# [1 3 1 3 2 1 3 2 3 3 2 2 2 1 2 1 1 2 1 3 2 2 2 2 3 1 2 1 1 1 3 1 3 3 2 3 3
#  3 3 2 2 1 2 2 1 3 3 1 3 2 1 3 3 3 1 3 3 1 1 2 1 2 2]
# Confusion Matrix:  [[15  0  1]
#  [ 0 21  0]
#  [ 5  0 21]]
# Accuracy :  90.47619047619048
# Report :                precision    recall  f1-score   support
#
#            1       0.75      0.94      0.83        16
#            2       1.00      1.00      1.00        21
#            3       0.95      0.81      0.88        26
#
#     accuracy                           0.90        63
#    macro avg       0.90      0.92      0.90        63
# weighted avg       0.92      0.90      0.91        63
#
# Results Using Entropy:
# Predicted values:
# [3 3 3 3 2 3 3 2 3 3 2 2 2 3 2 1 3 2 3 3 2 2 2 2 3 3 2 3 1 1 3 1 3 3 2 3 3
#  3 3 2 2 1 2 2 1 3 3 3 3 2 1 3 3 3 1 3 3 1 3 2 3 2 2]
# Confusion Matrix:  [[ 9  0  7]
#  [ 0 21  0]
#  [ 0  0 26]]
# Accuracy :  88.88888888888889
# ...

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(24,10))
tree.plot_tree(clf, filled=True, fontsize=10)
# Out:
# [Text(0.55, 0.9375, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.3, 0.8125, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.26, 0.6875, 'X[2] <= 2.765\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.12, 0.5625, 'X[0] <= 12.705\ngini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.08, 0.4375, 'X[2] <= 1.58\ngini = 0.5\nsamples = 8\nvalue = [4, 0, 4]'),
#  Text(0.04, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.12, 0.3125, 'X[0] <= 11.425\ngini = 0.444\nsamples = 6\nvalue = [2, 0, 4]'),
#  Text(0.08, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.16, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.16, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.4, 0.5625, 'X[0] <= 12.71\ngini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.32, 0.4375, 'X[2] <= 3.24\ngini = 0.034\nsamples = 58\nvalue = [1, 0, 57]'),
# ...

# %%
clf = tree.DecisionTreeClassifier(min_impurity_decrease=0.2)
clf.fit(X, y)
plt.figure(figsize=(18,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.5, 0.75, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.25, 0.25, 'gini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.75, 0.25, 'gini = 0.264\nsamples = 83\nvalue = [13, 70, 0]')]

# %%
clf = tree.DecisionTreeClassifier(max_depth=3)
clf.fit(X, y)
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.4583333333333333, 0.875, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.25, 0.625, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.16666666666666666, 0.375, 'X[2] <= 2.765\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.08333333333333333, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.25, 0.125, 'gini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.6666666666666666, 0.625, 'X[0] <= 16.7\ngini = 0.264\nsamples = 83\nvalue = [13, 70, 0]'),
#  Text(0.5, 0.375, 'X[2] <= 2.455\ngini = 0.499\nsamples = 23\nvalue = [12, 11, 0]'),
#  Text(0.4166666666666667, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.5833333333333334, 0.125, 'gini = 0.391\nsamples = 15\nvalue = [4, 11, 0]'),
#  Text(0.8333333333333334, 0.375, 'X[0] <= 17.1\ngini = 0.033\nsamples = 60\nvalue = [1, 59, 0]'),
# ...

# %%
clf = tree.DecisionTreeClassifier(max_depth=3,min_samples_leaf=3)
clf.fit(X, y)
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.4583333333333333, 0.875, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.25, 0.625, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.16666666666666666, 0.375, 'X[2] <= 2.765\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.08333333333333333, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.25, 0.125, 'gini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.6666666666666666, 0.625, 'X[0] <= 16.7\ngini = 0.264\nsamples = 83\nvalue = [13, 70, 0]'),
#  Text(0.5, 0.375, 'X[2] <= 2.455\ngini = 0.499\nsamples = 23\nvalue = [12, 11, 0]'),
#  Text(0.4166666666666667, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.5833333333333334, 0.125, 'gini = 0.391\nsamples = 15\nvalue = [4, 11, 0]'),
#  Text(0.8333333333333334, 0.375, 'X[0] <= 17.1\ngini = 0.033\nsamples = 60\nvalue = [1, 59, 0]'),
# ...

# %%
clf = tree.DecisionTreeClassifier(max_leaf_nodes=5)
clf.fit(X, y)
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.5555555555555556, 0.875, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.3333333333333333, 0.625, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.2222222222222222, 0.375, 'X[2] <= 2.765\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.7777777777777778, 0.625, 'X[0] <= 16.7\ngini = 0.264\nsamples = 83\nvalue = [13, 70, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.499\nsamples = 23\nvalue = [12, 11, 0]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.033\nsamples = 60\nvalue = [1, 59, 0]')]

# %%
dt = DecisionTreeClassifier(random_state=42)

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'min_impurity_decrease':[0.0,0.1,0.2,0.3,0.4],
    'max_leaf_nodes':[2,3,5,10,20],
    'criterion': ["gini", "entropy"]
}

# %%
# grid_search = GridSearchCV(estimator=dt, 
#                            param_grid=params, 
#                            cv=4, n_jobs=-1, verbose=1, scoring = "f1")

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-14823ef2b705> in <module>
#       1 # Instantiate the grid search model
# ----> 2 grid_search = GridSearchCV(estimator=dt,
#       3                            param_grid=params,
#       4                            cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")
#
# NameError: name 'GridSearchCV' is not defined

# %%
# %%time
grid_search.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# NameError: name 'grid_search' is not defined

# %%
score_df = pd.DataFrame(grid_search.cv_results_)
score_df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-760093905e23> in <module>
# ----> 1 score_df = pd.DataFrame(grid_search.cv_results_)
#       2 score_df.sample(5)
#
# NameError: name 'grid_search' is not defined
