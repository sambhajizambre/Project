# %% [markdown]
# <a href="https://colab.research.google.com/github/sambhajizambre/Project/blob/main/seed%20dataset%20decision%20tree%20classifier%20algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,roc_curve, classification_report

# %%
df=pd.read_excel('/content/drive/MyDrive/python/seeds_dataset.xlsx')
df.head(5)
# Out:
#     Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# 0                  2.221                    5.220             1
# 1                  1.018                    4.956             1
# 2                  2.699                    4.825             1
# 3                  2.259                    4.805             1
# 4                  1.355                    5.175             1

# %%
df.shape
# Out:
# (210, 8)

# %%
df.describe()
# Out:
#              Area   Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# count  210.000000  210.000000   210.000000        210.000000       210.000000
# mean    14.847524   14.559286     0.870999          5.628533         3.258605
# std      2.909699    1.305959     0.023629          0.443063         0.377714
# min     10.590000   12.410000     0.808100          4.899000         2.630000
# 25%     12.270000   13.450000     0.856900          5.262250         2.944000
# 50%     14.355000   14.320000     0.873450          5.523500         3.237000
# 75%     17.305000   15.715000     0.887775          5.979750         3.561750
# max     21.180000   17.250000     0.918300          6.675000         4.033000
#
#        Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# count             210.000000               210.000000    210.000000
# mean                3.700201                 5.408071      2.000000
# std                 1.503557                 0.491480      0.818448
# min                 0.765100                 4.519000      1.000000
# 25%                 2.561500                 5.045000      1.000000
# 50%                 3.599000                 5.223000      2.000000
# 75%                 4.768750                 5.877000      3.000000
# max                 8.456000                 6.550000      3.000000

# %%
df.isnull().sum()
# Out:
# Area                       0
# Perimeter                  0
# Compactness                0
# Length of Kernel           0
# Width of Kernel            0
# Asymmetry coefficient      0
# Length of kernel groove    0
# Class (1_2_3               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Area                     210 non-null    float64
#  1   Perimeter                210 non-null    float64
#  2   Compactness              210 non-null    float64
#  3   Length of Kernel         210 non-null    float64
#  4   Width of Kernel          210 non-null    float64
#  5   Asymmetry coefficient    210 non-null    float64
#  6   Length of kernel groove  210 non-null    float64
#  7   Class (1_2_3             210 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 13.2 KB

# %%
df=df.round(2)
df
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84         0.87              5.76             3.31
# 1    14.88      14.57         0.88              5.55             3.33
# 2    14.29      14.09         0.90              5.29             3.34
# 3    13.84      13.94         0.90              5.32             3.38
# 4    16.14      14.99         0.90              5.66             3.56
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20         0.88              5.14             2.98
# 206  11.23      12.88         0.85              5.14             2.80
# 207  13.20      13.66         0.89              5.24             3.23
# 208  11.84      13.21         0.85              5.18             2.84
# 209  12.30      13.34         0.87              5.24             2.97
#
#      Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# 0                     2.22                     5.22             1
# 1                     1.02                     4.96             1
# 2                     2.70                     4.82             1
# 3                     2.26                     4.80             1
# 4                     1.36                     5.18             1
# ..                     ...                      ...           ...
# 205                   3.63                     4.87             3
# 206                   4.32                     5.00             3
# 207                   8.32                     5.06             3
# 208                   3.60                     5.04             3
# 209                   5.64                     5.06             3
#
# [210 rows x 8 columns]

# %% [markdown]
# # heatmap

# %%
plt.figure(figsize=(8,8))
cor=df.corr()
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.ylim(8,0)
# Out:
# (8.0, 0.0)

# %% [markdown]
# # Distribution Plot for one by one variable

# %%
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Area'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Perimeter'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Compactness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Length of Kernel'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Width of Kernel'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Asymmetry coefficient'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Length of kernel groove'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Class (1_2_3'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# 0                    2.221                    5.220             1
# 1                    1.018                    4.956             1
# 2                    2.699                    4.825             1
# 3                    2.259                    4.805             1
# 4                    1.355                    5.175             1
# ..                     ...                      ...           ...
# 205                  3.631                    4.870             3
# 206                  4.325                    5.003             3
# 207                  8.315                    5.056             3
# 208                  3.598                    5.044             3
# 209                  5.637                    5.063             3
#
# [210 rows x 8 columns]

# %%
df
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84         0.87              5.76             3.31
# 1    14.88      14.57         0.88              5.55             3.33
# 2    14.29      14.09         0.90              5.29             3.34
# 3    13.84      13.94         0.90              5.32             3.38
# 4    16.14      14.99         0.90              5.66             3.56
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20         0.88              5.14             2.98
# 206  11.23      12.88         0.85              5.14             2.80
# 207  13.20      13.66         0.89              5.24             3.23
# 208  11.84      13.21         0.85              5.18             2.84
# 209  12.30      13.34         0.87              5.24             2.97
#
#      Asymmetry coefficient  Length of kernel groove  Class (1_2_3
# 0                     2.22                     5.22             1
# 1                     1.02                     4.96             1
# 2                     2.70                     4.82             1
# 3                     2.26                     4.80             1
# 4                     1.36                     5.18             1
# ..                     ...                      ...           ...
# 205                   3.63                     4.87             3
# 206                   4.32                     5.00             3
# 207                   8.32                     5.06             3
# 208                   3.60                     5.04             3
# 209                   5.64                     5.06             3
#
# [210 rows x 8 columns]

# %% [markdown]
# # checking VIF value

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df[['Area', 'Perimeter','Compactness','Length of Kernel','Width of Kernel','Asymmetry coefficient','Length of kernel groove']]
#VIF dataframe
vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
# calculating VIF for each feature
vif_df["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df)
# Out:
#                    feature           VIF
# 0                     Area   4695.485975
# 1                Perimeter  19229.360535
# 2              Compactness   5198.083692
# 3         Length of Kernel   7988.548677
# 4          Width of Kernel   7295.162001
# 5    Asymmetry coefficient      9.417769
# 6  Length of kernel groove   1318.561552

# %%
df1 = df.drop('Length of Kernel', axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df1[['Area', 'Perimeter','Compactness','Width of Kernel','Asymmetry coefficient','Length of kernel groove']]
#VIF dataframe
vif_df1 = pd.DataFrame()
vif_df1["feature"] = X.columns
# calculating VIF for each feature
vif_df1["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df1)
# Out:
#                    feature          VIF
# 0                     Area  5007.542466
# 1                Perimeter  7346.462439
# 2              Compactness  5671.598406
# 3          Width of Kernel  7535.139903
# 4    Asymmetry coefficient     9.415094
# 5  Length of kernel groove  1192.309544

# %%
df2 = df1.drop('Width of Kernel', axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df2[['Area', 'Perimeter','Compactness','Asymmetry coefficient','Length of kernel groove']]
#VIF dataframe
vif_df2 = pd.DataFrame()
vif_df2["feature"] = X.columns
# calculating VIF for each feature
vif_df2["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df2)
# Out:
#                    feature          VIF
# 0                     Area   657.981176
# 1                Perimeter  6194.656178
# 2              Compactness  1083.178962
# 3    Asymmetry coefficient     8.908273
# 4  Length of kernel groove  1020.231135

# %%
df2
# Out:
#       Area  Perimeter  Compactness  Asymmetry coefficient  \
# 0    15.26      14.84       0.8710                  2.221
# 1    14.88      14.57       0.8811                  1.018
# 2    14.29      14.09       0.9050                  2.699
# 3    13.84      13.94       0.8955                  2.259
# 4    16.14      14.99       0.9034                  1.355
# ..     ...        ...          ...                    ...
# 205  12.19      13.20       0.8783                  3.631
# 206  11.23      12.88       0.8511                  4.325
# 207  13.20      13.66       0.8883                  8.315
# 208  11.84      13.21       0.8521                  3.598
# 209  12.30      13.34       0.8684                  5.637
#
#      Length of kernel groove  Class (1_2_3
# 0                      5.220             1
# 1                      4.956             1
# 2                      4.825             1
# 3                      4.805             1
# 4                      5.175             1
# ..                       ...           ...
# 205                    4.870             3
# 206                    5.003             3
# 207                    5.056             3
# 208                    5.044             3
# 209                    5.063             3
#
# [210 rows x 6 columns]

# %%
df3 = df2.drop('Length of kernel groove', axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df3[['Area', 'Perimeter','Compactness','Asymmetry coefficient']]
#VIF dataframe
vif_df3 = pd.DataFrame()
vif_df3["feature"] = X.columns
# calculating VIF for each feature
vif_df3["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df3)
# Out:
#                  feature          VIF
# 0                   Area   471.891071
# 1              Perimeter  2337.265074
# 2            Compactness   770.006906
# 3  Asymmetry coefficient     7.681930

# %%
plt.figure(figsize=(8,8))
cor=df3.corr()
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.ylim(8,0)
# Out:
# (8.0, 0.0)

# %%
df4 = df3.drop('Perimeter', axis=1)
df4
# Out:
#       Area  Compactness  Asymmetry coefficient  Class (1_2_3
# 0    15.26       0.8710                  2.221             1
# 1    14.88       0.8811                  1.018             1
# 2    14.29       0.9050                  2.699             1
# 3    13.84       0.8955                  2.259             1
# 4    16.14       0.9034                  1.355             1
# ..     ...          ...                    ...           ...
# 205  12.19       0.8783                  3.631             3
# 206  11.23       0.8511                  4.325             3
# 207  13.20       0.8883                  8.315             3
# 208  11.84       0.8521                  3.598             3
# 209  12.30       0.8684                  5.637             3
#
# [210 rows x 4 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df4[['Area','Compactness','Asymmetry coefficient']]
#VIF dataframe
vif_df4 = pd.DataFrame()
vif_df4["feature"] = X.columns
# calculating VIF for each feature
vif_df4["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_df4)
# Out:
#                  feature        VIF
# 0                   Area  33.678296
# 1            Compactness  46.100426
# 2  Asymmetry coefficient   7.125954

# %%
plt.figure(figsize=(8,8))
cor=df4.corr()
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.ylim(8,0)
# Out:
# (8.0, 0.0)

# %%
#--Checking Outliers
plt.figure(figsize=(15,15))
pos = 1
for i in df.columns:
    plt.subplot(3, 4, pos)
    sns.boxplot(df[i])
    pos += 1
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
col_names=['Area', 'Perimeter', 'Compactness', 'Length of Kernel',
       'Width of Kernel', 'Asymmetry coefficient', 'Length of kernel groove']
display(col_names)
for i in col_names:
    q1, q2, q3 = df[i].quantile([0.25,0.5,0.75])
    IQR = q3 - q1
    lower_cap=q1-1.5*IQR
    upper_cap=q3+1.5*IQR
    df[i]=df[i].apply(lambda x: upper_cap if x>(upper_cap) else (lower_cap if x<(lower_cap) else x))
# Out:
# ['Area',
#  'Perimeter',
#  'Compactness',
#  'Length of Kernel',
#  'Width of Kernel',
#  'Asymmetry coefficient',
#  'Length of kernel groove']

# %%
sns.pairplot(df);

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),
            annot=True,
            linewidths=.5,
            center=0,
            cbar=False,
            cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['Class (1_2_3']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Decision Tree classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
X=df4.drop('Class (1_2_3',axis=1)
y=df4['Class (1_2_3']

# %%
dt.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=3,test_size=0.30)

# %%
dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred=dt.predict(X_test)
y_test_prob=dt.predict_proba(X_test)

# %%
print ('Confusion Matrix -Test :','\n',confusion_matrix(y_test,y_test_pred))

print ('Overall accuracy -Test :',accuracy_score(y_test,y_test_pred))


print ('AUC -Test :', roc_auc_score(y_test,y_test_prob,multi_class='ovr'))
# Out:
# Confusion Matrix -Test :
#  [[21  1  0]
#  [ 1 22  0]
#  [ 1  0 17]]
# Overall accuracy -Test : 0.9523809523809523
# AUC -Test : 0.9636218583859093

# %%
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.91      0.95      0.93        22
#            2       0.96      0.96      0.96        23
#            3       1.00      0.94      0.97        18
#
#     accuracy                           0.95        63
#    macro avg       0.96      0.95      0.95        63
# weighted avg       0.95      0.95      0.95        63

# %% [markdown]
# # Acurracy testing using hyperparameter

# %%
# Function to split the dataset
def splitdataset(df):
# Separating the target variable
	X = df.drop(['Class (1_2_3'], axis=1)
	Y = df['Class (1_2_3']

	# Splitting the dataset into train and test
	X_train, X_test, y_train, y_test = train_test_split(
	X, Y, test_size = 0.3, random_state = 100)
	
	return X, Y, X_train, X_test, y_train, y_test
# Function to perform training with giniIndex.
def train_using_gini(X_train, X_test, y_train):

	# Creating the classifier object
	clf_gini = DecisionTreeClassifier(criterion = "gini",
			random_state = 100,max_depth=3, min_samples_leaf=5)

	# Performing training
	clf_gini.fit(X_train, y_train)
	return clf_gini
	
# Function to perform training with entropy.
def tarin_using_entropy(X_train, X_test, y_train):

	# Decision tree with entropy
	clf_entropy = DecisionTreeClassifier(
			criterion = "entropy", random_state = 100,
			max_depth = 3, min_samples_leaf = 5)

	# Performing training
	clf_entropy.fit(X_train, y_train)
	return clf_entropy


# Function to make predictions
def prediction(X_test, clf_object):

	# Predicton on test with giniIndex
	y_pred = clf_object.predict(X_test)
	print("Predicted values:")
	print(y_pred)
	return y_pred
	
# Function to calculate accuracy
def cal_accuracy(y_test, y_pred):
	
	print("Confusion Matrix: ",
		confusion_matrix(y_test, y_pred))
	
	print ("Accuracy : ",
	accuracy_score(y_test,y_pred)*100)
	
	print("Report : ",
	classification_report(y_test, y_pred))

# Driver code
def main():
	
	# Building Phase
	data = df
	X, Y, X_train, X_test, y_train, y_test = splitdataset(data)
	clf_gini = train_using_gini(X_train, X_test, y_train)
	clf_entropy = tarin_using_entropy(X_train, X_test, y_train)
	
	# Operational Phase
	print("Results Using Gini Index:")
	
	# Prediction using gini
	y_pred_gini = prediction(X_test, clf_gini)
	cal_accuracy(y_test, y_pred_gini)
	
	print("Results Using Entropy:")
	# Prediction using entropy
	y_pred_entropy = prediction(X_test, clf_entropy)
	cal_accuracy(y_test, y_pred_entropy)
	
	
# Calling main function
if __name__=="__main__":
	main()
# Out:
# Results Using Gini Index:
# Predicted values:
# [1 3 1 3 2 1 3 2 3 3 2 2 2 1 2 1 1 2 1 3 2 2 2 2 3 1 2 1 1 1 3 1 3 3 2 3 3
#  3 3 2 2 1 2 2 1 3 3 1 3 2 1 3 3 3 1 3 3 1 1 2 1 2 2]
# Confusion Matrix:  [[15  0  1]
#  [ 0 21  0]
#  [ 5  0 21]]
# Accuracy :  90.47619047619048
# Report :                precision    recall  f1-score   support
#
#            1       0.75      0.94      0.83        16
#            2       1.00      1.00      1.00        21
#            3       0.95      0.81      0.88        26
#
#     accuracy                           0.90        63
#    macro avg       0.90      0.92      0.90        63
# weighted avg       0.92      0.90      0.91        63
#
# Results Using Entropy:
# Predicted values:
# [3 3 3 3 2 3 3 2 3 3 2 2 2 3 2 1 3 2 3 3 2 2 2 2 3 3 2 3 1 1 3 1 3 3 2 3 3
#  3 3 2 2 1 2 2 1 3 3 3 3 2 1 3 3 3 1 3 3 1 3 2 3 2 2]
# Confusion Matrix:  [[ 9  0  7]
#  [ 0 21  0]
#  [ 0  0 26]]
# Accuracy :  88.88888888888889
# Report :                precision    recall  f1-score   support
#
#            1       1.00      0.56      0.72        16
#            2       1.00      1.00      1.00        21
#            3       0.79      1.00      0.88        26
#
#     accuracy                           0.89        63
#    macro avg       0.93      0.85      0.87        63
# weighted avg       0.91      0.89      0.88        63

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(24,10))
tree.plot_tree(clf, filled=True, fontsize=10)
# Out:
# [Text(0.5357142857142857, 0.9285714285714286, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.30952380952380953, 0.7857142857142857, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.2619047619047619, 0.6428571428571429, 'X[2] <= 2.764\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.14285714285714285, 0.5, 'X[0] <= 12.705\ngini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.09523809523809523, 0.35714285714285715, 'X[2] <= 1.581\ngini = 0.5\nsamples = 8\nvalue = [4, 0, 4]'),
#  Text(0.047619047619047616, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.14285714285714285, 0.21428571428571427, 'X[0] <= 11.425\ngini = 0.444\nsamples = 6\nvalue = [2, 0, 4]'),
#  Text(0.09523809523809523, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.19047619047619047, 0.07142857142857142, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.19047619047619047, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.38095238095238093, 0.5, 'X[0] <= 12.71\ngini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.2857142857142857, 0.35714285714285715, 'X[1] <= 0.89\ngini = 0.034\nsamples = 58\nvalue = [1, 0, 57]'),
#  Text(0.23809523809523808, 0.21428571428571427, 'gini = 0.0\nsamples = 57\nvalue = [0, 0, 57]'),
#  Text(0.3333333333333333, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.47619047619047616, 0.35714285714285715, 'X[2] <= 4.414\ngini = 0.426\nsamples = 13\nvalue = [4, 0, 9]'),
#  Text(0.42857142857142855, 0.21428571428571427, 'X[2] <= 3.1\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 1]'),
#  Text(0.38095238095238093, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.47619047619047616, 0.07142857142857142, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.5238095238095238, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8]'),
#  Text(0.35714285714285715, 0.6428571428571429, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.7619047619047619, 0.7857142857142857, 'X[0] <= 16.7\ngini = 0.264\nsamples = 83\nvalue = [13, 70, 0]'),
#  Text(0.6666666666666666, 0.6428571428571429, 'X[2] <= 2.455\ngini = 0.499\nsamples = 23\nvalue = [12, 11, 0]'),
#  Text(0.6190476190476191, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.7142857142857143, 0.5, 'X[2] <= 5.562\ngini = 0.391\nsamples = 15\nvalue = [4, 11, 0]'),
#  Text(0.6666666666666666, 0.35714285714285715, 'X[1] <= 0.882\ngini = 0.337\nsamples = 14\nvalue = [3, 11, 0]'),
#  Text(0.6190476190476191, 0.21428571428571427, 'X[1] <= 0.871\ngini = 0.469\nsamples = 8\nvalue = [3, 5, 0]'),
#  Text(0.5714285714285714, 0.07142857142857142, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.6666666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.7142857142857143, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.7619047619047619, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8571428571428571, 0.6428571428571429, 'X[1] <= 0.908\ngini = 0.033\nsamples = 60\nvalue = [1, 59, 0]'),
#  Text(0.8095238095238095, 0.5, 'gini = 0.0\nsamples = 57\nvalue = [0, 57, 0]'),
#  Text(0.9047619047619048, 0.5, 'X[0] <= 17.69\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.8571428571428571, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9523809523809523, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]')]

# %%
clf = tree.DecisionTreeClassifier(min_impurity_decrease=0.2)
clf.fit(X, y)
plt.figure(figsize=(18,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.5, 0.75, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.25, 0.25, 'gini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.75, 0.25, 'gini = 0.264\nsamples = 83\nvalue = [13, 70, 0]')]

# %%
clf = tree.DecisionTreeClassifier(max_depth=3)
clf.fit(X, y)
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.4583333333333333, 0.875, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.25, 0.625, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.16666666666666666, 0.375, 'X[2] <= 2.764\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.08333333333333333, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.25, 0.125, 'gini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.6666666666666666, 0.625, 'X[0] <= 16.7\ngini = 0.264\nsamples = 83\nvalue = [13, 70, 0]'),
#  Text(0.5, 0.375, 'X[2] <= 2.455\ngini = 0.499\nsamples = 23\nvalue = [12, 11, 0]'),
#  Text(0.4166666666666667, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.5833333333333334, 0.125, 'gini = 0.391\nsamples = 15\nvalue = [4, 11, 0]'),
#  Text(0.8333333333333334, 0.375, 'X[1] <= 0.908\ngini = 0.033\nsamples = 60\nvalue = [1, 59, 0]'),
#  Text(0.75, 0.125, 'gini = 0.0\nsamples = 57\nvalue = [0, 57, 0]'),
#  Text(0.9166666666666666, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [1, 2, 0]')]

# %%
clf = tree.DecisionTreeClassifier(max_depth=3,min_samples_leaf=3)
clf.fit(X, y)
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.4583333333333333, 0.875, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.25, 0.625, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.16666666666666666, 0.375, 'X[2] <= 2.764\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.08333333333333333, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.25, 0.125, 'gini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.6666666666666666, 0.625, 'X[0] <= 16.7\ngini = 0.264\nsamples = 83\nvalue = [13, 70, 0]'),
#  Text(0.5, 0.375, 'X[2] <= 2.455\ngini = 0.499\nsamples = 23\nvalue = [12, 11, 0]'),
#  Text(0.4166666666666667, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.5833333333333334, 0.125, 'gini = 0.391\nsamples = 15\nvalue = [4, 11, 0]'),
#  Text(0.8333333333333334, 0.375, 'X[1] <= 0.908\ngini = 0.033\nsamples = 60\nvalue = [1, 59, 0]'),
#  Text(0.75, 0.125, 'gini = 0.0\nsamples = 57\nvalue = [0, 57, 0]'),
#  Text(0.9166666666666666, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [1, 2, 0]')]

# %%
clf = tree.DecisionTreeClassifier(max_leaf_nodes=5)
clf.fit(X, y)
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, fontsize=14)
# Out:
# [Text(0.5555555555555556, 0.875, 'X[0] <= 15.37\ngini = 0.667\nsamples = 210\nvalue = [70, 70, 70]'),
#  Text(0.3333333333333333, 0.625, 'X[0] <= 13.41\ngini = 0.495\nsamples = 127\nvalue = [57, 0, 70]'),
#  Text(0.2222222222222222, 0.375, 'X[2] <= 2.764\ngini = 0.278\nsamples = 84\nvalue = [14, 0, 70]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [9, 0, 4]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.131\nsamples = 71\nvalue = [5, 0, 66]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.7777777777777778, 0.625, 'X[0] <= 16.7\ngini = 0.264\nsamples = 83\nvalue = [13, 70, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.499\nsamples = 23\nvalue = [12, 11, 0]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.033\nsamples = 60\nvalue = [1, 59, 0]')]
