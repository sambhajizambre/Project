# %% [markdown]
# <a href="https://colab.research.google.com/github/sambhajizambre/Project/blob/main/capstone%20project%20_bengaluru_cafe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df=pd.read_csv('/content/drive/MyDrive/python/Bangalore_Cafe_Zomato.csv')
df.head(10)
# Out:
#                                                 name online_order book_table  \
# 0                                    San Churro Cafe          Yes         No
# 1                                     Penthouse Cafe          Yes         No
# 2                                          Smacznego          Yes         No
# 3  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# 4                                       Cafe Shuffle          Yes        Yes
# 5                                   The Coffee Shack          Yes        Yes
# 6                                         Caf-Eleven           No         No
# 7                                    San Churro Cafe          Yes         No
# 8                                      Cafe Vivacity          Yes         No
# 9                                       Catch-up-ino          Yes         No
#
#     rate  votes      location            rest_type  \
# 0  3.8/5    918  Banashankari  Cafe, Casual Dining
# ...

# %%
df.tail(10)
# Out:
#                                                name online_order book_table  \
# 4367                                Cafe Coffee Day          Yes         No
# 4368                             Fashion Knack Cafe           No         No
# 4369                                  Butterly Cafe           No         No
# 4370                                Spice Boulevard           No         No
# 4371                            The Waverly Express           No         No
# 4372                                       Tata Cha          Yes         No
# 4373                                        Teashot           No         No
# 4374                     The Coffee Bean & Tea Leaf          Yes         No
# 4375                                     Cafe Thulp          Yes         No
# 4376  Re:fuel- Aloft Bengaluru Cessna Business Park           No         No
#
#         rate  votes                    location     rest_type  \
# 4367  3.6 /5     45                  Whitefield          Cafe
# ...

# %%
df.describe()
# Out:
#               votes
# count   4377.000000
# mean     436.056203
# std     1100.397778
# min        0.000000
# 25%       24.000000
# 50%       99.000000
# 75%      450.000000
# max    14726.000000

# %%
df.shape
# Out:
# (4377, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4377 entries, 0 to 4376
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         4377 non-null   object
#  1   online_order                 4377 non-null   object
#  2   book_table                   4377 non-null   object
#  3   rate                         4126 non-null   object
#  4   votes                        4377 non-null   int64
#  5   location                     4377 non-null   object
#  6   rest_type                    4377 non-null   object
#  7   dish_liked                   2881 non-null   object
#  8   cuisines                     4377 non-null   object
#  9   approx_cost(for two people)  4332 non-null   object
#  10  listed_in(type)              3713 non-null   object
#  11  listed_in(city)              3713 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 410.5+ KB

# %%
df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                            251
# votes                             0
# location                          0
# rest_type                         0
# dish_liked                     1496
# cuisines                          0
# approx_cost(for two people)      45
# listed_in(type)                 664
# listed_in(city)                 664
# dtype: int64

# %%
df1=df.groupby('location')
df1.first()
# Out:
#                                                       name online_order  \
# location
# BTM                                     Hearts Unlock Cafe           No
# Banashankari                               San Churro Cafe          Yes
# Banaswadi                                      Cafe Nibras           No
# Bannerghatta Road                              Tisano Cafe          Yes
# Basavanagudi                                     Redberrys          Yes
# ...                                                    ...          ...
# Vasanth Nagar                               The Culinarium           No
# Vijay Nagar                                Cafe Coffee Day          Yes
# Whitefield         Bloomsbury's Global Kitchen & Bakehouse          Yes
# Wilson Garden                              Cafe Coffee Day           No
# Yeshwantpur                                       Tuckinto          Yes
#
#                   book_table    rate  votes             rest_type  \
# location
# ...

# %%
df=df.drop('listed_in(type)',axis=1)

# %%
df.head()
# Out:
#                                                 name online_order book_table  \
# 0                                    San Churro Cafe          Yes         No
# 1                                     Penthouse Cafe          Yes         No
# 2                                          Smacznego          Yes         No
# 3  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# 4                                       Cafe Shuffle          Yes        Yes
#
#     rate  votes      location            rest_type  \
# 0  3.8/5    918  Banashankari  Cafe, Casual Dining
# 1  4.0/5    324  Banashankari                 Cafe
# 2  4.2/5    504  Banashankari                 Cafe
# 3  4.1/5    402  Banashankari                 Cafe
# 4  4.2/5    150  Banashankari                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# ...

# %%
n = df.nunique(axis=0)
n
# Out:
# name                           494
# online_order                     2
# book_table                       2
# rate                            51
# votes                          691
# location                        64
# rest_type                        9
# dish_liked                     483
# cuisines                       251
# approx_cost(for two people)     25
# listed_in(city)                 30
# dtype: int64

# %%
n = df.groupby('listed_in(city)')
n.first()
# Out:
#                                                                    name  \
# listed_in(city)
# BTM                                                        Mudpipe Cafe
# Banashankari                                            San Churro Cafe
# Bannerghatta Road                                        Crave Bit Cafe
# Basavanagudi                                            San Churro Cafe
# Bellandur                                                    Story Time
# Brigade Road                                        The Flying Squirrel
# Brookefield                                           Breads and Banter
# Church Street          Moto Store & CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ©
# Electronic City                                       The Platonic Cafe
# Frazer Town                                                 Mambos Cafe
# HSR                                               Amour Fine Patisserie
# Indiranagar                                                    Cafe Max
# ...

# %%
df = df.groupby('listed_in(city)')['quantity'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-4f3c41c6a08c> in <module>()
# ----> 1 df = df.groupby('listed_in(city)')['quantity'].nunique()
#       2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: quantity'
